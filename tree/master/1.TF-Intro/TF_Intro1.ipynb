# %% [markdown]
# <a href="https://colab.research.google.com/github/siddhantjain07/Tensorflow-in-Practice/blob/master/tree/master/1.TF-Intro/TF_Intro1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Setup

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %% [markdown]
# ##Defining model

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, 0.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %% [markdown]
# ##Training model

# %%
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 2ms/step - loss: 56.0355
# Epoch 2/500
# 1/1 [==============================] - 0s 1ms/step - loss: 44.4126
# Epoch 3/500
# 1/1 [==============================] - 0s 3ms/step - loss: 35.2620
# Epoch 4/500
# 1/1 [==============================] - 0s 1ms/step - loss: 28.0567
# Epoch 5/500
# 1/1 [==============================] - 0s 1ms/step - loss: 22.3820
# Epoch 6/500
# 1/1 [==============================] - 0s 2ms/step - loss: 17.9116
# Epoch 7/500
# 1/1 [==============================] - 0s 2ms/step - loss: 14.3888
# Epoch 8/500
# 1/1 [==============================] - 0s 1ms/step - loss: 11.6116
# Epoch 9/500
# 1/1 [==============================] - 0s 2ms/step - loss: 9.4212
# Epoch 10/500
# 1/1 [==============================] - 0s 2ms/step - loss: 7.6925
# Epoch 11/500
# 1/1 [==============================] - 0s 2ms/step - loss: 6.3273
# Epoch 12/500
# 1/1 [==============================] - 0s 2ms/step - loss: 5.2480
# ...

# %%
print(model.predict([10.0]))
# Out:
# [[18.417524]]

# %% [markdown]
# ##Housing price prediction

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
def house_model(y_new):
  xs = np.array([1.0, 2.0, 4.0, 3.0, 5.0, 9.0, 8.0, 6.0], dtype=float)
  ys = np.array([1.0, 1.5, 2.5, 2.0, 3.0, 5.0, 4.5, 3.5], dtype=float)
  model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
  model.compile(optimizer='sgd', loss='mean_squared_error')
  model.fit(xs, ys, epochs=500)
  return model.predict(y_new)[0]

# %%
prediction = house_model([7.0])
print(prediction)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 1ms/step - loss: 58.7343
# Epoch 2/500
# 1/1 [==============================] - 0s 2ms/step - loss: 9.1598
# Epoch 3/500
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4411
# Epoch 4/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2392
# Epoch 5/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0519
# Epoch 6/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0226
# Epoch 7/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0179
# Epoch 8/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0170
# Epoch 9/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0168
# Epoch 10/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0166
# Epoch 11/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0165
# Epoch 12/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0163
# ...
